# %%
import pandas as pd

# %%
location = "Recreation_Spring_Programs.csv"
df = pd.read_csv(location)

# %%
df.head()
# Out:
#         Season Primary Category Secondary Category  \
# 0  Spring 2019           Sports   Ultimate Frisbee
# 1  Spring 2019            Dance           Ballroom
# 2  Spring 2019    Arts & Crafts            Jewelry
# 3  Spring 2019            Dance            Hip Hop
# 4  Spring 2019            Dance            Hip Hop
#
#                                ActivityName  \
# 0  High School Ultimate Frisbee Free Agents
# 1                  Beginner Argentine Tango
# 2                         Fiber Art Jewelry
# 3                              Hip Hop kids
# 4                               Hippo Hoppo
#
#                                          Description  ActivityNumber  \
# 0  If you are an individual interested in playing...           56308
# 1  For questions contact Avant Garde Ballroom at ...           64172
# 2  Learn the techniques to create beautiful Vinta...           63998
# 3  Get ready to pop, lock and rock your body in t...           63588
# ...

# %%
df.columns
# Out:
# Index(['Season', 'Primary Category', 'Secondary Category', 'ActivityName',
#        'Description', 'ActivityNumber', 'Ages', 'Location', 'Address', 'City',
#        'State', 'Zip', 'Activity Facility', 'Start Date', 'End Date',
#        'Start Time', 'End Time', 'Sessions', 'Days of the Week', 'Fee',
#        'Status', 'Address/Location'],
#       dtype='object')
